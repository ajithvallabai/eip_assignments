50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3938 - acc: 0.8647 - val_loss: 0.5871 - val_acc: 0.8192
# Epoch 32/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3989 - acc: 0.8648 - val_loss: 0.6071 - val_acc: 0.8115
# Epoch 33/50
# 390/390 [==============================] - 12s 31ms/step - loss: 0.3988 - acc: 0.8648 - val_loss: 0.5761 - val_acc: 0.8184
# Epoch 34/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3824 - acc: 0.8693 - val_loss: 0.6022 - val_acc: 0.8155
# Epoch 35/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3895 - acc: 0.8667 - val_loss: 0.5619 - val_acc: 0.8211
# Epoch 36/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3806 - acc: 0.8708 - val_loss: 0.5542 - val_acc: 0.8245
# Epoch 37/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3785 - acc: 0.8722 - val_loss: 0.6172 - val_acc: 0.8123
# Epoch 38/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3723 - acc: 0.8751 - val_loss: 0.5785 - val_acc: 0.8219
# Epoch 39/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3625 - acc: 0.8762 - val_loss: 0.5741 - val_acc: 0.8223
# Epoch 40/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3554 - acc: 0.8791 - val_loss: 0.5803 - val_acc: 0.8233
# Epoch 41/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3622 - acc: 0.8791 - val_loss: 0.5915 - val_acc: 0.8191
# Epoch 42/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3520 - acc: 0.8798 - val_loss: 0.6000 - val_acc: 0.8233
# Epoch 43/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3481 - acc: 0.8821 - val_loss: 0.6018 - val_acc: 0.8244
# Epoch 44/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3510 - acc: 0.8819 - val_loss: 0.5724 - val_acc: 0.8275
# Epoch 45/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3449 - acc: 0.8842 - val_loss: 0.5895 - val_acc: 0.8233
# Epoch 46/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3367 - acc: 0.8871 - val_loss: 0.5943 - val_acc: 0.8246
# Epoch 47/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3376 - acc: 0.8891 - val_loss: 0.5757 - val_acc: 0.8306
# Epoch 48/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3383 - acc: 0.8874 - val_loss: 0.6052 - val_acc: 0.8217
# Epoch 49/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3363 - acc: 0.8874 - val_loss: 0.6077 - val_acc: 0.8207
# Epoch 50/50
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3338 - acc: 0.8886 - val_loss: 0.5915 - val_acc: 0.8214
# Model took 598.31 seconds to train
# Accuracy on test data is: 82.14

# %% [markdown]
# ## final Base Accuracy after 50 epochs - 82.14 - highest 83.06

# %% [markdown]
# ## Modified network

# %%
from keras.layers.convolutional import SeparableConv2D
from keras.layers import GlobalAveragePooling2D,Dropout,AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import LearningRateScheduler

# %%
from keras.optimizers import SGD,Adam
sgd = SGD(momentum=0.9)

# %%
# Define the model
model = Sequential()
model.add(SeparableConv2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.1))


model.add(SeparableConv2D(64, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.1))

model.add(SeparableConv2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(SeparableConv2D(128, 3, 3))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(AveragePooling2D(pool_size=(2, 2))) # 15 6
model.add(Dropout(0.2))

model.add(SeparableConv2D(32, 1, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())


#------
model.add(SeparableConv2D(32, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(SeparableConv2D(64, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(SeparableConv2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(SeparableConv2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(SeparableConv2D(32, 1, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())

#--------

model.add(SeparableConv2D(32, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(SeparableConv2D(64, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(SeparableConv2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(SeparableConv2D(32, 1, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(SeparableConv2D(64, 3, 3))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(SeparableConv2D(10, 1, 1))

model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(GlobalAveragePooling2D())
model.add(Activation('softmax'))

model.summary()
# Compile the model
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3), padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3))`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:46: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:64: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:69: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:81: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:85: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (3, 3))`
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_333 (Separa (None, 32, 32, 32)        155
# _________________________________________________________________
# activation_350 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_329 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# separable_conv2d_334 (Separa (None, 32, 32, 64)        2400
# _________________________________________________________________
# activation_351 (Activation)  (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_330 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# separable_conv2d_335 (Separa (None, 32, 32, 128)       8896
# _________________________________________________________________
# activation_352 (Activation)  (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_331 (Bat (None, 32, 32, 128)       512
# _________________________________________________________________
# separable_conv2d_336 (Separa (None, 30, 30, 128)       17664
# _________________________________________________________________
# activation_353 (Activation)  (None, 30, 30, 128)       0
# _________________________________________________________________
# batch_normalization_332 (Bat (None, 30, 30, 128)       512
# _________________________________________________________________
# average_pooling2d_26 (Averag (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 15, 15, 128)       0
# _________________________________________________________________
# separable_conv2d_337 (Separa (None, 15, 15, 32)        4256
# _________________________________________________________________
# activation_354 (Activation)  (None, 15, 15, 32)        0
# _________________________________________________________________
# batch_normalization_333 (Bat (None, 15, 15, 32)        128
# _________________________________________________________________
# separable_conv2d_338 (Separa (None, 15, 15, 32)        1344
# _________________________________________________________________
# activation_355 (Activation)  (None, 15, 15, 32)        0
# _________________________________________________________________
# batch_normalization_334 (Bat (None, 15, 15, 32)        128
# _________________________________________________________________
# separable_conv2d_339 (Separa (None, 15, 15, 64)        2400
# _________________________________________________________________
# activation_356 (Activation)  (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_335 (Bat (None, 15, 15, 64)        256
# _________________________________________________________________
# separable_conv2d_340 (Separa (None, 15, 15, 128)       8896
# _________________________________________________________________
# activation_357 (Activation)  (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_336 (Bat (None, 15, 15, 128)       512
# _________________________________________________________________
# separable_conv2d_341 (Separa (None, 15, 15, 128)       17664
# _________________________________________________________________
# activation_358 (Activation)  (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_337 (Bat (None, 15, 15, 128)       512
# _________________________________________________________________
# average_pooling2d_27 (Averag (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_183 (Dropout)        (None, 7, 7, 128)         0
# _________________________________________________________________
# separable_conv2d_342 (Separa (None, 7, 7, 32)          4256
# _________________________________________________________________
# activation_359 (Activation)  (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_338 (Bat (None, 7, 7, 32)          128
# _________________________________________________________________
# separable_conv2d_343 (Separa (None, 7, 7, 32)          1344
# _________________________________________________________________
# activation_360 (Activation)  (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_339 (Bat (None, 7, 7, 32)          128
# _________________________________________________________________
# separable_conv2d_344 (Separa (None, 7, 7, 64)          2400
# _________________________________________________________________
# activation_361 (Activation)  (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_340 (Bat (None, 7, 7, 64)          256
# _________________________________________________________________
# separable_conv2d_345 (Separa (None, 7, 7, 128)         8896
# _________________________________________________________________
# activation_362 (Activation)  (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_341 (Bat (None, 7, 7, 128)         512
# _________________________________________________________________
# average_pooling2d_28 (Averag (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_184 (Dropout)        (None, 3, 3, 128)         0
# _________________________________________________________________
# separable_conv2d_346 (Separa (None, 3, 3, 32)          4256
# _________________________________________________________________
# activation_363 (Activation)  (None, 3, 3, 32)          0
# _________________________________________________________________
# batch_normalization_342 (Bat (None, 3, 3, 32)          128
# _________________________________________________________________
# separable_conv2d_347 (Separa (None, 1, 1, 64)          2400
# _________________________________________________________________
# activation_364 (Activation)  (None, 1, 1, 64)          0
# _________________________________________________________________
# batch_normalization_343 (Bat (None, 1, 1, 64)          256
# _________________________________________________________________
# separable_conv2d_348 (Separa (None, 1, 1, 10)          714
# _________________________________________________________________
# activation_365 (Activation)  (None, 1, 1, 10)          0
# _________________________________________________________________
# batch_normalization_344 (Bat (None, 1, 1, 10)          40
# _________________________________________________________________
# global_average_pooling2d_22  (None, 10)                0
# _________________________________________________________________
# activation_366 (Activation)  (None, 10)                0
# =================================================================
# Total params: 92,333
# Trainable params: 90,137
# Non-trainable params: 2,196
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:90: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(10, (1, 1))`

# %%
# !ls
# Out:
# sample_data

# %%
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(shear_range=0.3,
                             zoom_range=0.3,                             
                             horizontal_flip=True)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1
                                 )
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#   del sys.path[0]
# Epoch 1/50
# 390/390 [==============================] - 49s 125ms/step - loss: 1.9345 - acc: 0.2961 - val_loss: 1.9253 - val_acc: 0.3285
# Epoch 2/50
# 390/390 [==============================] - 29s 75ms/step - loss: 1.6588 - acc: 0.3989 - val_loss: 1.7126 - val_acc: 0.3887
# Epoch 3/50
# 390/390 [==============================] - 29s 75ms/step - loss: 1.5402 - acc: 0.4439 - val_loss: 1.6375 - val_acc: 0.4311
# Epoch 4/50
# 390/390 [==============================] - 29s 75ms/step - loss: 1.4559 - acc: 0.4751 - val_loss: 1.5847 - val_acc: 0.4466
# Epoch 5/50
# 390/390 [==============================] - 29s 75ms/step - loss: 1.3784 - acc: 0.5035 - val_loss: 1.3659 - val_acc: 0.5184
50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.6310 - acc: 0.7792 - val_loss: 0.6118 - val_acc: 0.7891
# Epoch 30/50
# 390/390 [==============================] - 29s 75ms/step - loss: 0.6211 - acc: 0.7838 - val_loss: 0.7647 - val_acc: 0.7469
# Epoch 31/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.6189 - acc: 0.7854 - val_loss: 0.5865 - val_acc: 0.8009
# Epoch 32/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.6012 - acc: 0.7933 - val_loss: 0.6556 - val_acc: 0.7789
# Epoch 33/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5987 - acc: 0.7915 - val_loss: 0.5830 - val_acc: 0.7989
# Epoch 34/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5883 - acc: 0.7950 - val_loss: 0.5846 - val_acc: 0.7961
# Epoch 35/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5775 - acc: 0.7991 - val_loss: 0.5792 - val_acc: 0.8055
# Epoch 36/50
# 390/390 [==============================] - 29s 75ms/step - loss: 0.5762 - acc: 0.8001 - val_loss: 0.6453 - val_acc: 0.7825
# Epoch 37/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5686 - acc: 0.8007 - val_loss: 0.5410 - val_acc: 0.8158
# Epoch 38/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5520 - acc: 0.8086 - val_loss: 0.5603 - val_acc: 0.8081
# Epoch 39/50
# 390/390 [==============================] - 29s 74ms/step - loss: 0.5527 - acc: 0.8091 - val_loss: 0.6905 - val_acc: 0.7697
# Epoch 40/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5484 - acc: 0.8097 - val_loss: 0.6598 - val_acc: 0.7790
# Epoch 41/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5398 - acc: 0.8114 - val_loss: 0.6341 - val_acc: 0.7865
# Epoch 42/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5357 - acc: 0.8151 - val_loss: 0.5477 - val_acc: 0.8166
# Epoch 43/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5305 - acc: 0.8168 - val_loss: 0.6230 - val_acc: 0.7898
# Epoch 44/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5263 - acc: 0.8175 - val_loss: 0.5302 - val_acc: 0.8244
# Epoch 45/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5138 - acc: 0.8211 - val_loss: 0.5517 - val_acc: 0.8153
# Epoch 46/50
# 390/390 [==============================] - 28s 72ms/step - loss: 0.5122 - acc: 0.8215 - val_loss: 0.5561 - val_acc: 0.8124
# Epoch 47/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5096 - acc: 0.8249 - val_loss: 0.5104 - val_acc: 0.8300
# Epoch 48/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.5023 - acc: 0.8272 - val_loss: 0.6437 - val_acc: 0.7917
# Epoch 49/50
# 390/390 [==============================] - 28s 73ms/step - loss: 0.4948 - acc: 0.8290 - val_loss: 0.5037 - val_acc: 0.8308
# Epoch 50/50
# 390/390 [==============================] - 29s 73ms/step - loss: 0.4907 - acc: 0.8293 - val_loss: 0.5081 - val_acc: 0.8310
# Model took 1463.28 seconds to train
# Accuracy on test data is: 83.10

# %% [markdown]
# ## Modified network accuracy is 83.10
