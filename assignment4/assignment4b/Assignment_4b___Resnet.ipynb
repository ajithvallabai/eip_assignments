# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D,GlobalAveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 47:
        lr *= 0.5e-3
    elif epoch > 40:
        lr *= 1e-3
    elif epoch > 30:
        lr *= 1e-2
    elif epoch > 25:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    
    # x=Conv2D(num_classes,
    #               kernel_size=(3,3),      
    #               kernel_initializer='he_normal',
    #               kernel_regularizer=l2(1e-4))(x)
    # x = BatchNormalization()(x)
    # x = Activation('relu')(x)
    # x = GlobalAveragePooling2D()(x)
    # #y = Flatten()(x)
    
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)

    outputs= x
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    print("version 1")
    model = resnet_v1(input_shape=input_shape, depth=depth)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# version 1

# %%
from keras.optimizers import SGD

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr_schedule(0)),metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# # Run training, with or without data augmentation.
# if not data_augmentation:
#     print('Not using data augmentation.')
#     model.fit(x_train, y_train,
#               batch_size=batch_size,
#               epochs=epochs,
#               validation_data=(x_test, y_test),
#               shuffle=True,
#               callbacks=callbacks)
# else:
#     print('Using real-time data augmentation.')
#     # This will do preprocessing and realtime data augmentation:
#     datagen = ImageDataGenerator(
#         # set input mean to 0 over the dataset
#         featurewise_center=False,
#         # set each sample mean to 0
#         samplewise_center=False,
#         # divide inputs by std of dataset
#         featurewise_std_normalization=False,
#         # divide each input by its std
#         samplewise_std_normalization=False,
#         # apply ZCA whitening
#         zca_whitening=False,
#         # epsilon for ZCA whitening
#         zca_epsilon=1e-06,
#         # randomly rotate images in the range (deg 0 to 180)
#         rotation_range=0,
#         # randomly shift images horizontally
#         width_shift_range=0.3,
#         # randomly shift images vertically
#         height_shift_range=0.3,
#         # set range for random shear
#         shear_range=0.,
#         # set range for random zoom
#         zoom_range=0.,
#         # set range for random channel shifts
#         channel_shift_range=0.,
#         # set mode for filling points outside the input boundaries
#         fill_mode='nearest',
#         # value used for fill_mode = "constant"
#         cval=0.,
#         # randomly flip images
#         horizontal_flip=True,
#         # randomly flip images
#         vertical_flip=False,
#         # set rescaling factor (applied before any other transformation)
#         rescale=None,
#         # set function that will be applied on each input
#         preprocessing_function=None,
#         # image data format, either "channels_first" or "channels_last"
#         data_format=None,
#         # fraction of images reserved for validation (strictly between 0 and 1)
#         validation_split=0.0)

#     # Compute quantities required for featurewise normalization
#     # (std, mean, and principal components if ZCA whitening is applied).
#     datagen.fit(x_train)

#     # Fit the model on the batches generated by datagen.flow().
#     model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
#                         validation_data=(x_test, y_test),
#                         epochs=epochs, verbose=1, workers=4,
#                         callbacks=callbacks)

# # Score trained model.
# scores = model.evaluate(x_test, y_test, verbose=1)
# print('Test loss:', scores[0])
# print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 32, 32, 16)   448         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 32, 32, 16)   64          conv2d_152[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 32, 32, 16)   0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 32, 32, 16)   2320        activation_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 32, 32, 16)   64          conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 32, 32, 16)   0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 32, 32, 16)   2320        activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 32, 32, 16)   64          conv2d_154[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 32, 32, 16)   0           activation_137[0][0]
#                                                                  batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 32, 32, 16)   0           add_64[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 32, 32, 16)   2320        activation_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 32, 32, 16)   64          conv2d_155[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 32, 32, 16)   0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 32, 32, 16)   2320        activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 32, 32, 16)   64          conv2d_156[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 32, 32, 16)   0           activation_139[0][0]
#                                                                  batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 32, 32, 16)   0           add_65[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 16)   2320        activation_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 32, 32, 16)   64          conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 32, 32, 16)   0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 32, 32, 16)   2320        activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 32, 32, 16)   64          conv2d_158[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 32, 32, 16)   0           activation_141[0][0]
#                                                                  batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 32, 32, 16)   0           add_66[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 16, 16, 32)   4640        activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 16, 16, 32)   128         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 16, 16, 32)   0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 16, 16, 32)   9248        activation_144[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 16, 16, 32)   544         activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 16, 16, 32)   128         conv2d_160[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 16, 16, 32)   0           conv2d_161[0][0]
#                                                                  batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 16, 16, 32)   0           add_67[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 16, 16, 32)   9248        activation_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 16, 16, 32)   128         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 16, 16, 32)   0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 16, 16, 32)   9248        activation_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 16, 16, 32)   128         conv2d_163[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 16, 16, 32)   0           activation_145[0][0]
#                                                                  batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 16, 16, 32)   0           add_68[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 16, 16, 32)   9248        activation_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 16, 16, 32)   128         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 16, 16, 32)   0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 16, 16, 32)   9248        activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 16, 16, 32)   128         conv2d_165[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 16, 16, 32)   0           activation_147[0][0]
#                                                                  batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 16, 16, 32)   0           add_69[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 8, 8, 64)     18496       activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 8, 8, 64)     256         conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 8, 8, 64)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 8, 8, 64)     36928       activation_150[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 8, 8, 64)     2112        activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 8, 8, 64)     256         conv2d_167[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 8, 8, 64)     0           conv2d_168[0][0]
#                                                                  batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 8, 8, 64)     0           add_70[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 8, 8, 64)     36928       activation_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 8, 8, 64)     256         conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 8, 8, 64)     0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 8, 8, 64)     36928       activation_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 8, 8, 64)     256         conv2d_170[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 8, 8, 64)     0           activation_151[0][0]
#                                                                  batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 8, 8, 64)     0           add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 8, 8, 64)     36928       activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 8, 8, 64)     256         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 8, 8, 64)     0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 8, 8, 64)     36928       activation_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 8, 8, 64)     256         conv2d_172[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 8, 8, 64)     0           activation_153[0][0]
#                                                                  batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 8, 8, 64)     0           add_72[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 64)     0           activation_155[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           650         flatten_3[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# print('Not using data augmentation.')
# model.fit(x_train, y_train,
#               batch_size=batch_size,
#               epochs=3,
#               validation_data=(x_test, y_test),
#               shuffle=True,
#               callbacks=callbacks)
# Out:
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/3
# Learning rate:  0.001
# 50000/50000 [==============================] - 41s 830us/step - loss: 2.0706 - acc: 0.2937 - val_loss: 1.9626 - val_acc: 0.3381
#
# Epoch 00001: val_acc improved from -inf to 0.33810, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/3
# Learning rate:  0.001
# 50000/50000 [==============================] - 36s 726us/step - loss: 1.8486 - acc: 0.3836 - val_loss: 1.8121 - val_acc: 0.3987
#
# Epoch 00002: val_acc improved from 0.33810 to 0.39870, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/3
# Learning rate:  0.001
# 50000/50000 [==============================] - 36s 722us/step - loss: 1.7559 - acc: 0.4205 - val_loss: 1.7548 - val_acc: 0.4218
#
# Epoch 00003: val_acc improved from 0.39870 to 0.42180, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5

# %%
print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

#    # Compute quantities required for featurewise normalization
#    # (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

#    # Fit the model on the batches generated by datagen.flow().
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=50, verbose=1,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 58s 147ms/step - loss: 1.6880 - acc: 0.4520 - val_loss: 1.7512 - val_acc: 0.4520
#
# Epoch 00001: val_acc improved from -inf to 0.45200, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 1.2720 - acc: 0.5968 - val_loss: 1.4653 - val_acc: 0.5507
#
# Epoch 00002: val_acc improved from 0.45200 to 0.55070, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 1.0961 - acc: 0.6633 - val_loss: 1.2160 - val_acc: 0.6360
#
# Epoch 00003: val_acc improved from 0.55070 to 0.63600, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.9767 - acc: 0.7081 - val_loss: 0.9958 - val_acc: 0.7102
#
# Epoch 00004: val_acc improved from 0.63600 to 0.71020, saving model to /content/saved_models/cifar10_ResNet20v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8922 - acc: 0.7387 - val_loss: 1.1336 - val_acc: 0.6661
#
# Epoch 00005: val_acc did not improve from 0.71020
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8327 - acc: 0.7585 - val_loss: 1.2379 - val_acc: 0.6558
#
# Epoch 00006: val_acc did not improve from 0.71020
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7877 - acc: 0.7750 - val_loss: 1.0861 - val_acc: 0.7083
#
# Epoch 00007: val_acc did not improve from 0.71020
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.7476 - acc: 0.7888 - val_loss: 0.9918 - val_acc: 0.7196
#
# Epoch 00008: val_acc improved from 0.71020 to 0.71960, saving model to /content/saved_models/cifar10_ResNet20v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.7101 - acc: 0.8038 - val_loss: 0.8082 - val_acc: 0.7707
#
# Epoch 00009: val_acc improved from 0.71960 to 0.77070, saving model to /content/saved_models/cifar10_ResNet20v1_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.6877 - acc: 0.8107 - val_loss: 0.8356 - val_acc: 0.7604
#
# Epoch 00010: val_acc did not improve from 0.77070
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.6618 - acc: 0.8195 - val_loss: 1.0098 - val_acc: 0.7213
#
# Epoch 00011: val_acc did not improve from 0.77070
# Epoch 12/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.6389 - acc: 0.8271 - val_loss: 0.8037 - val_acc: 0.7763
#
# Epoch 00012: val_acc improved from 0.77070 to 0.77630, saving model to /content/saved_models/cifar10_ResNet20v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.6181 - acc: 0.8337 - val_loss: 0.9815 - val_acc: 0.7316
#
# Epoch 00013: val_acc did not improve from 0.77630
# Epoch 14/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.6038 - acc: 0.8401 - val_loss: 0.8189 - val_acc: 0.7742
#
# Epoch 00014: val_acc did not improve from 0.77630
# Epoch 15/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.5857 - acc: 0.8459 - val_loss: 0.8210 - val_acc: 0.7726
#
# Epoch 00015: val_acc did not improve from 0.77630
# Epoch 16/50
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.5758 - acc: 0.8501 - val_loss: 1.1500 - val_acc: 0.7048
#
# Epoch 00016: val_acc did not improve from 0.77630
# Epoch 17/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.5583 - acc: 0.8555 - val_loss: 0.8701 - val_acc: 0.7727
#
# Epoch 00017: val_acc did not improve from 0.77630
# Epoch 18/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.5513 - acc: 0.8580 - val_loss: 0.7193 - val_acc: 0.8021
#
# Epoch 00018: val_acc improved from 0.77630 to 0.80210, saving model to /content/saved_models/cifar10_ResNet20v1_model.018.h5
# Epoch 19/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.5363 - acc: 0.8643 - val_loss: 0.9325 - val_acc: 0.7465
#
# Epoch 00019: val_acc did not improve from 0.80210
# Epoch 20/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.5254 - acc: 0.8684 - val_loss: 0.7897 - val_acc: 0.7888
#
# Epoch 00020: val_acc did not improve from 0.80210
# Epoch 21/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.5227 - acc: 0.8690 - val_loss: 0.6226 - val_acc: 0.8426
#
# Epoch 00021: val_acc improved from 0.80210 to 0.84260, saving model to /content/saved_models/cifar10_ResNet20v1_model.021.h5
# Epoch 22/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.5129 - acc: 0.8730 - val_loss: 0.6396 - val_acc: 0.8324
#
# Epoch 00022: val_acc did not improve from 0.84260
# Epoch 23/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.5075 - acc: 0.8748 - val_loss: 0.8937 - val_acc: 0.7658
#
# Epoch 00023: val_acc did not improve from 0.84260
# Epoch 24/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.4972 - acc: 0.8763 - val_loss: 0.6875 - val_acc: 0.8251
#
# Epoch 00024: val_acc did not improve from 0.84260
# Epoch 25/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.4922 - acc: 0.8784 - val_loss: 0.7547 - val_acc: 0.7978
#
# Epoch 00025: val_acc did not improve from 0.84260
# Epoch 26/50
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.4831 - acc: 0.8819 - val_loss: 1.0743 - val_acc: 0.7318
#
# Epoch 00026: val_acc did not improve from 0.84260
# Epoch 27/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.4073 - acc: 0.9108 - val_loss: 0.5219 - val_acc: 0.8755
#
# Epoch 00027: val_acc improved from 0.84260 to 0.87550, saving model to /content/saved_models/cifar10_ResNet20v1_model.027.h5
# Epoch 28/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3803 - acc: 0.9188 - val_loss: 0.5200 - val_acc: 0.8739
#
# Epoch 00028: val_acc did not improve from 0.87550
# Epoch 29/50
# Learning rate:  0.0001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3694 - acc: 0.9230 - val_loss: 0.5076 - val_acc: 0.8792
#
# Epoch 00029: val_acc improved from 0.87550 to 0.87920, saving model to /content/saved_models/cifar10_ResNet20v1_model.029.h5
# Epoch 30/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3619 - acc: 0.9255 - val_loss: 0.5147 - val_acc: 0.8768
#
# Epoch 00030: val_acc did not improve from 0.87920
# Epoch 31/50
# Learning rate:  0.0001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3565 - acc: 0.9271 - val_loss: 0.4992 - val_acc: 0.8805
#
# Epoch 00031: val_acc improved from 0.87920 to 0.88050, saving model to /content/saved_models/cifar10_ResNet20v1_model.031.h5
# Epoch 32/50
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3454 - acc: 0.9306 - val_loss: 0.4955 - val_acc: 0.8817
#
# Epoch 00032: val_acc improved from 0.88050 to 0.88170, saving model to /content/saved_models/cifar10_ResNet20v1_model.032.h5
# Epoch 33/50
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3436 - acc: 0.9314 - val_loss: 0.4971 - val_acc: 0.8811
#
# Epoch 00033: val_acc did not improve from 0.88170
# Epoch 34/50
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3409 - acc: 0.9318 - val_loss: 0.4961 - val_acc: 0.8820
#
# Epoch 00034: val_acc improved from 0.88170 to 0.88200, saving model to /content/saved_models/cifar10_ResNet20v1_model.034.h5
# Epoch 35/50
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3407 - acc: 0.9311 - val_loss: 0.4949 - val_acc: 0.8827
#
# Epoch 00035: val_acc improved from 0.88200 to 0.88270, saving model to /content/saved_models/cifar10_ResNet20v1_model.035.h5
# Epoch 36/50
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3381 - acc: 0.9331 - val_loss: 0.4953 - val_acc: 0.8824
#
# Epoch 00036: val_acc did not improve from 0.88270
# Epoch 37/50
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3398 - acc: 0.9302 - val_loss: 0.4938 - val_acc: 0.8826
#
# Epoch 00037: val_acc did not improve from 0.88270
# Epoch 38/50
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3372 - acc: 0.9325 - val_loss: 0.4949 - val_acc: 0.8831
#
# Epoch 00038: val_acc improved from 0.88270 to 0.88310, saving model to /content/saved_models/cifar10_ResNet20v1_model.038.h5
# Epoch 39/50
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3355 - acc: 0.9337 - val_loss: 0.4967 - val_acc: 0.8821
#
# Epoch 00039: val_acc did not improve from 0.88310
# Epoch 40/50
# Learning rate:  1e-05
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3378 - acc: 0.9328 - val_loss: 0.4948 - val_acc: 0.8817
#
# Epoch 00040: val_acc did not improve from 0.88310
# Epoch 41/50
# Learning rate:  1e-05
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3378 - acc: 0.9336 - val_loss: 0.4927 - val_acc: 0.8825
#
# Epoch 00041: val_acc did not improve from 0.88310
# Epoch 42/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3330 - acc: 0.9344 - val_loss: 0.4946 - val_acc: 0.8809
#
# Epoch 00042: val_acc did not improve from 0.88310
# Epoch 43/50
# Learning rate:  1e-06
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3342 - acc: 0.9337 - val_loss: 0.4934 - val_acc: 0.8820
#
# Epoch 00043: val_acc did not improve from 0.88310
# Epoch 44/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3342 - acc: 0.9337 - val_loss: 0.4933 - val_acc: 0.8818
#
# Epoch 00044: val_acc did not improve from 0.88310
# Epoch 45/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 115ms/step - loss: 0.3339 - acc: 0.9352 - val_loss: 0.4945 - val_acc: 0.8821
#
# Epoch 00045: val_acc did not improve from 0.88310
# Epoch 46/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3360 - acc: 0.9336 - val_loss: 0.4939 - val_acc: 0.8821
#
# Epoch 00046: val_acc did not improve from 0.88310
# Epoch 47/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3291 - acc: 0.9374 - val_loss: 0.4950 - val_acc: 0.8821
#
# Epoch 00047: val_acc did not improve from 0.88310
# Epoch 48/50
# Learning rate:  1e-06
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3329 - acc: 0.9353 - val_loss: 0.4932 - val_acc: 0.8825
#
# Epoch 00048: val_acc did not improve from 0.88310
# Epoch 49/50
# Learning rate:  5e-07
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3328 - acc: 0.9345 - val_loss: 0.4933 - val_acc: 0.8822
#
# Epoch 00049: val_acc did not improve from 0.88310
# Epoch 50/50
# Learning rate:  5e-07
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3298 - acc: 0.9362 - val_loss: 0.4928 - val_acc: 0.8822
#
# Epoch 00050: val_acc did not improve from 0.88310

# %%
import cv2

# %%
(x_train_1 ,y_train_1), (x_test_1, y_test_1) = cifar10.load_data()

# %%
sample=x_train_1[:10]

# %%
for image in sample:
  print(image.shape)
  x = image
  x = np.expand_dims(x, axis=0)
  

  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  
  class_output = model.output[:, class_idx]
  #class_output = model.output[:, 836]
  last_conv_layer = model.get_layer("conv2d_171")

  grads = K.gradients(class_output, last_conv_layer.output)[0]
  
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(64):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis = -1)
  
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)

  heatmap = cv2.resize(heatmap, (128, 128))
  image_input=image.copy()
  image_input1= image_input
  image_input= image_input.astype('uint8')
  image_input=cv2.resize(image_input,(128,128))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(image_input, 0.5, heatmap, 0.5, 0)
  from google.colab.patches import cv2_imshow
  # print("actual class - " + str(class_names[ydf['actual'][image]]))
  # print("predicted class - " + str(class_names[ydf['predicted'][image]]))
  #print("No - "+ str(image))

  cv2_imshow(image_input)
  cv2_imshow(superimposed_img)
# Out:
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D3637B8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D3637B8>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D31FA90>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D31F978>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D2DAD68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D2DAD68>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D298F60>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D298F60>
# (32, 32, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D25B358>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D25B278>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D21B630>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D21B630>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D1D6908>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D1D6898>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D195BE0>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D195BE0>
# (32, 32, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D150EB8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D150DD8>
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D10EF60>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F8A0D1D6E80>
